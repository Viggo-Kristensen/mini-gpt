# %% [markdown]
# <a href="https://colab.research.google.com/github/Viggo-Kristensen/mini-gpt/blob/main/experiment-notebooks/layer-normalization-experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Layer Norm Experimentation**

# %% [markdown]
# ## **Imports**

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Uploading data**

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-b5caa001-1577-417c-86e3-d4704870708e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5caa001-1577-417c-86e3-d4704870708e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **Unzipping Files**

# %%
import zipfile
import os

zip_filename = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall("unzipped_folder")

# %%
no_norm = pd.read_csv("no_norm.csv").drop(columns="Unnamed: 0")
norm = pd.read_csv("norm.csv").drop(columns="Unnamed: 0")

# %% [markdown]
# ## **Plotting Data**

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4.5))

axes[0].plot(no_norm["step"], no_norm["train_loss_list"], label="train loss", color="#2B5FA5")
axes[0].plot(no_norm["step"], no_norm["test_loss_list"], label="test loss", color="#7BC67E")
axes[1].plot(norm["step"], norm["train_loss_list"], label="train loss", color="#2B5FA5")
axes[1].plot(norm["step"], norm["test_loss_list"], label="test loss", color="#7BC67E")
axes[0].set_xlabel("step")
axes[1].set_xlabel("step")
axes[0].set_ylabel("average loss over 2500 steps")
axes[1].set_ylabel("average loss over 2500 steps")
axes[0].legend()
axes[1].legend()
axes[0].set_title("Without layer norm")
axes[1].set_title("With layer norm")
# Out:
# Text(0.5, 1.0, 'With layer norm')
